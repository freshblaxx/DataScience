# %%
from torch import no_grad, tensor
from torch.nn import LSTM, Linear, Module, MSELoss
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset


def prepare_dataset_for_lstm(series, seq_length: int = 4):
    setX: list = []
    setY: list = []
    for i in range(len(series) - seq_length):
        past = series[i : i + seq_length]
        future = series[i + 1 : i + seq_length + 1]
        setX.append(past)
        setY.append(future)
    return tensor(setX), tensor(setY)


class DS_LSTM(Module):
    def __init__(self, train, input_size: int = 1, hidden_size: int = 50, num_layers: int = 1, length: int = 4):
        super().__init__()
        self.lstm = LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers, batch_first=True)
        self.linear = Linear(hidden_size, 1)
        self.optimizer = Adam(self.parameters())
        self.loss_fn = MSELoss()

        trnX, trnY = prepare_dataset_for_lstm(train, seq_length=length)
        self.loader = DataLoader(TensorDataset(trnX, trnY), shuffle=True, batch_size=len(train) // 10)

    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.linear(x)
        return x

    def fit(self):
        self.train()
        for batchX, batchY in self.loader:
            y_pred = self(batchX)
            loss = self.loss_fn(y_pred, batchY)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
        return loss

    def predict(self, X):
        with no_grad():
            y_pred = self(X)
        return y_pred[:, -1, :]

# %%
from pandas import read_csv, DataFrame, Series
from dslabs_functions import series_train_test_split

filename: str = "/Users/dominikfrank/Library/Mobile Documents/com~apple~CloudDocs/Desktop/University/Master/Semester 1/PII/Data Science/Code for Project/DataScience/forecast_ny_arrests.csv"
file_tag: str = "ny_arrests"
target: str = "Manhattan"
timecol: str = "Date"

measure: str = "R2"

data: DataFrame = read_csv(filename, index_col=timecol, sep=";", decimal=".", parse_dates=True)
series = data[[target]].values.astype("float32")

train_size = int(len(series) * 0.90)
train, test = series[:train_size], series[train_size:]

# %%
model = DS_LSTM(train, input_size=1, hidden_size=50, num_layers=1)
loss = model.fit()
print(loss)
# Out:
# tensor(97951.3359, grad_fn=<MseLossBackward0>)

# %%
from dslabs_functions import HEIGHT, plot_multiline_chart
from copy import deepcopy

from matplotlib.pyplot import figure, savefig, subplots
from dslabs_functions import FORECAST_MEASURES, DELTA_IMPROVE, plot_multiline_chart


def lstm_study(train, test, nr_episodes: int = 1000, measure: str = "R2"):
    sequence_size = [2, 4, 8]
    nr_hidden_units = [25, 50, 100]

    step: int = nr_episodes // 10
    episodes = [1] + list(range(0, nr_episodes + 1, step))[1:]
    flag = measure == "R2" or measure == "MAPE"
    best_model = None
    best_params: dict = {"name": "LSTM", "metric": measure, "params": ()}
    best_performance: float = -100000

    _, axs = subplots(1, len(sequence_size), figsize=(len(sequence_size) * HEIGHT, HEIGHT))

    for i in range(len(sequence_size)):
        length = sequence_size[i]
        tstX, tstY = prepare_dataset_for_lstm(test, seq_length=length)

        values = {}
        for hidden in nr_hidden_units:
            yvalues = []
            model = DS_LSTM(train, hidden_size=hidden)
            for n in range(0, nr_episodes + 1):
                model.fit()
                if n % step == 0:
                    prd_tst = model.predict(tstX)
                    eval: float = FORECAST_MEASURES[measure](test[length:], prd_tst)
                    print(f"seq length={length} hidden_units={hidden} nr_episodes={n}", eval)
                    if eval > best_performance and abs(eval - best_performance) > DELTA_IMPROVE:
                        best_performance: float = eval
                        best_params["params"] = (length, hidden, n)
                        best_model = deepcopy(model)
                    yvalues.append(eval)
            values[hidden] = yvalues
        plot_multiline_chart(
            episodes,
            values,
            ax=axs[i],
            title=f"LSTM seq length={length} ({measure})",
            xlabel="nr episodes",
            ylabel=measure,
            percentage=flag,
        )
    print(
        f"LSTM best results achieved with length={best_params["params"][0]} hidden_units={best_params["params"][1]} and nr_episodes={best_params["params"][2]}) ==> measure={best_performance:.2f}"
    )
    return best_model, best_params


best_model, best_params = lstm_study(train, test, nr_episodes=3000, measure=measure)
# Out:
# seq length=2 hidden_units=25 nr_episodes=0 -5.303786277770996
# seq length=2 hidden_units=25 nr_episodes=300 -0.11235105991363525
# seq length=2 hidden_units=25 nr_episodes=600 -0.620058536529541
# seq length=2 hidden_units=25 nr_episodes=900 -0.5544440746307373
# seq length=2 hidden_units=25 nr_episodes=1200 -0.44248712062835693
# seq length=2 hidden_units=25 nr_episodes=1500 -0.6461671590805054
# seq length=2 hidden_units=25 nr_episodes=1800 -0.5373389720916748
# seq length=2 hidden_units=25 nr_episodes=2100 -0.3813357353210449
# seq length=2 hidden_units=25 nr_episodes=2400 -0.38327085971832275
# seq length=2 hidden_units=25 nr_episodes=2700 -0.4345550537109375
# seq length=2 hidden_units=25 nr_episodes=3000 -0.23902428150177002
# seq length=2 hidden_units=50 nr_episodes=0 -5.339390754699707
# seq length=2 hidden_units=50 nr_episodes=300 -0.554633378982544
# seq length=2 hidden_units=50 nr_episodes=600 -0.38103389739990234
# seq length=2 hidden_units=50 nr_episodes=900 -0.24336230754852295
# seq length=2 hidden_units=50 nr_episodes=1200 -0.5366579294204712
# seq length=2 hidden_units=50 nr_episodes=1500 -0.49151647090911865
# seq length=2 hidden_units=50 nr_episodes=1800 -0.4234508275985718
# seq length=2 hidden_units=50 nr_episodes=2100 -0.320812463760376
# seq length=2 hidden_units=50 nr_episodes=2400 -0.3719921112060547
# seq length=2 hidden_units=50 nr_episodes=2700 -0.45805823802948
# seq length=2 hidden_units=50 nr_episodes=3000 -0.29181933403015137
# seq length=2 hidden_units=100 nr_episodes=0 -5.2884745597839355
# seq length=2 hidden_units=100 nr_episodes=300 -0.34849703311920166
# seq length=2 hidden_units=100 nr_episodes=600 -0.4595680236816406
# seq length=2 hidden_units=100 nr_episodes=900 -0.25134336948394775
# seq length=2 hidden_units=100 nr_episodes=1200 -0.233320951461792
# seq length=2 hidden_units=100 nr_episodes=1500 -0.46287715435028076
# seq length=2 hidden_units=100 nr_episodes=1800 -0.35697078704833984
# seq length=2 hidden_units=100 nr_episodes=2100 -0.4092838764190674
# seq length=2 hidden_units=100 nr_episodes=2400 -0.4298708438873291
# seq length=2 hidden_units=100 nr_episodes=2700 -0.46128249168395996
# seq length=2 hidden_units=100 nr_episodes=3000 -0.3347238302230835
# seq length=4 hidden_units=25 nr_episodes=0 -5.3255791664123535
# seq length=4 hidden_units=25 nr_episodes=300 -0.06927108764648438
# seq length=4 hidden_units=25 nr_episodes=600 -0.2685658931732178
# seq length=4 hidden_units=25 nr_episodes=900 -0.18667268753051758
# seq length=4 hidden_units=25 nr_episodes=1200 -0.05137515068054199
# seq length=4 hidden_units=25 nr_episodes=1500 -0.03914201259613037
# seq length=4 hidden_units=25 nr_episodes=1800 -0.04660689830780029
# seq length=4 hidden_units=25 nr_episodes=2100 -0.030613303184509277
# seq length=4 hidden_units=25 nr_episodes=2400 -0.07837557792663574
# seq length=4 hidden_units=25 nr_episodes=2700 -0.10606801509857178
# seq length=4 hidden_units=25 nr_episodes=3000 -0.03275144100189209
# seq length=4 hidden_units=50 nr_episodes=0 -5.297377586364746
# seq length=4 hidden_units=50 nr_episodes=300 -0.19761741161346436
# seq length=4 hidden_units=50 nr_episodes=600 -0.020041942596435547
# seq length=4 hidden_units=50 nr_episodes=900 -0.05432891845703125
# seq length=4 hidden_units=50 nr_episodes=1200 -0.04724717140197754
# seq length=4 hidden_units=50 nr_episodes=1500 -0.010918498039245605
# seq length=4 hidden_units=50 nr_episodes=1800 -0.04335606098175049
# seq length=4 hidden_units=50 nr_episodes=2100 0.00938946008682251
# seq length=4 hidden_units=50 nr_episodes=2400 0.01141124963760376
# seq length=4 hidden_units=50 nr_episodes=2700 0.03508496284484863
# seq length=4 hidden_units=50 nr_episodes=3000 -0.0056313276290893555
# seq length=4 hidden_units=100 nr_episodes=0 -5.287933349609375
# seq length=4 hidden_units=100 nr_episodes=300 -0.13897168636322021
# seq length=4 hidden_units=100 nr_episodes=600 0.0578271746635437
# seq length=4 hidden_units=100 nr_episodes=900 0.04035466909408569
# seq length=4 hidden_units=100 nr_episodes=1200 -0.051706552505493164
# seq length=4 hidden_units=100 nr_episodes=1500 0.00717538595199585
# seq length=4 hidden_units=100 nr_episodes=1800 0.018625915050506592
# seq length=4 hidden_units=100 nr_episodes=2100 0.00435715913772583
# seq length=4 hidden_units=100 nr_episodes=2400 -0.057117462158203125
# seq length=4 hidden_units=100 nr_episodes=2700 -0.08998870849609375
# seq length=4 hidden_units=100 nr_episodes=3000 -0.10646355152130127
# seq length=8 hidden_units=25 nr_episodes=0 -7.118086814880371
# seq length=8 hidden_units=25 nr_episodes=300 -0.07109475135803223
# seq length=8 hidden_units=25 nr_episodes=600 -0.028503775596618652
# seq length=8 hidden_units=25 nr_episodes=900 0.13560819625854492
# seq length=8 hidden_units=25 nr_episodes=1200 0.14278680086135864
# seq length=8 hidden_units=25 nr_episodes=1500 0.24026960134506226
# seq length=8 hidden_units=25 nr_episodes=1800 0.1279696226119995
# seq length=8 hidden_units=25 nr_episodes=2100 0.020804882049560547
# seq length=8 hidden_units=25 nr_episodes=2400 0.1596495509147644
# seq length=8 hidden_units=25 nr_episodes=2700 -0.08351194858551025
# seq length=8 hidden_units=25 nr_episodes=3000 -0.15593385696411133
# seq length=8 hidden_units=50 nr_episodes=0 -7.146581649780273
# seq length=8 hidden_units=50 nr_episodes=300 0.2666475176811218
# seq length=8 hidden_units=50 nr_episodes=600 0.08881855010986328
# seq length=8 hidden_units=50 nr_episodes=900 0.022545576095581055
# seq length=8 hidden_units=50 nr_episodes=1200 -0.22270536422729492
# seq length=8 hidden_units=50 nr_episodes=1500 -0.22781431674957275
# seq length=8 hidden_units=50 nr_episodes=1800 -0.2218480110168457
# seq length=8 hidden_units=50 nr_episodes=2100 -0.2946040630340576
# seq length=8 hidden_units=50 nr_episodes=2400 -0.2794908285140991
# seq length=8 hidden_units=50 nr_episodes=2700 -0.2874053716659546
# seq length=8 hidden_units=50 nr_episodes=3000 -0.21622049808502197
# seq length=8 hidden_units=100 nr_episodes=0 -6.985647201538086
# seq length=8 hidden_units=100 nr_episodes=300 0.26684796810150146
# seq length=8 hidden_units=100 nr_episodes=600 0.13468408584594727
# seq length=8 hidden_units=100 nr_episodes=900 0.19337797164916992
# seq length=8 hidden_units=100 nr_episodes=1200 0.14918673038482666
# seq length=8 hidden_units=100 nr_episodes=1500 0.1285947561264038
# seq length=8 hidden_units=100 nr_episodes=1800 0.1570117473602295
# seq length=8 hidden_units=100 nr_episodes=2100 0.03845036029815674
# seq length=8 hidden_units=100 nr_episodes=2400 -0.027711153030395508
# seq length=8 hidden_units=100 nr_episodes=2700 0.05014151334762573
# seq length=8 hidden_units=100 nr_episodes=3000 -0.004215717315673828
# LSTM best results achieved with length=8 hidden_units=50 and nr_episodes=300) ==> measure=0.27

# %%
from dslabs_functions import plot_forecasting_eval

params = best_params["params"]
best_length = params[0]
trnX, trnY = prepare_dataset_for_lstm(train, seq_length=best_length)
tstX, tstY = prepare_dataset_for_lstm(test, seq_length=best_length)

prd_trn = best_model.predict(trnX)
prd_tst = best_model.predict(tstX)

plot_forecasting_eval(
    train[best_length:],
    test[best_length:],
    prd_trn,
    prd_tst,
    title=f"{file_tag} - LSTM (length={best_length}, hidden={params[1]}, epochs={params[2]})",
)
savefig(f"images/{file_tag}_lstms_{measure}_eval.png")

# %%
from dslabs_functions import plot_forecasting_series

series = data[[target]]
train, test = series[:train_size], series[train_size:]
pred_series: Series = Series(prd_tst.numpy().ravel(), index=test.index[best_length:])

plot_forecasting_series(
    train[best_length:],
    test[best_length:],
    pred_series,
    title=f"{file_tag} - LSTMs ",
    xlabel=timecol,
    ylabel=target,
)
savefig(f"images/{file_tag}_lstms_{measure}_forecast.png")
