# %%
from pandas import read_csv, DataFrame
import numpy as np

data: DataFrame = read_csv("class_ny_arrests.csv",index_col="ARREST_KEY", na_values={"", "UNKNOWN"})

# %%
data.head()
data = data.sample(n=10000, random_state=1)
data.head()
# Out:
#            ARREST_DATE  PD_CD                                PD_DESC  KY_CD  \
# ARREST_KEY
# 173644106   01/15/2018  109.0               ASSAULT 2,1,UNCLASSIFIED  106.0
# 83480788    03/04/2012  101.0                              ASSAULT 3  344.0
# 87189586    10/11/2012  744.0                         BAIL JUMPING 3  359.0
# 34021522    08/27/2007  478.0        THEFT OF SERVICES, UNCLASSIFIED  343.0
# 63162514    06/26/2009  503.0  CONTROLLED SUBSTANCE,INTENT TO SELL 3  117.0
#
#                                          OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# ARREST_KEY
# 173644106                           FELONY ASSAULT  PL 1200502          F
# 83480788              ASSAULT 3 & RELATED OFFENSES  PL 1200001          M
# 87189586    OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 2155500          M
# 34021522           OTHER OFFENSES RELATED TO THEFT  PL 1651503          M
# 63162514                           DANGEROUS DRUGS  PL 2201601          F
#
#            ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# ARREST_KEY
# 173644106            Q              103                0.0     25-44        M
# 83480788             M               18                0.0     18-24        M
# 87189586             Q              102                0.0     25-44        M
# 34021522             B               40                0.0     25-44        M
# 63162514             S              122                0.0       65+        F
#
#            PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude
# ARREST_KEY
# 173644106      BLACK   1040260.0    193180.0  40.696742 -73.798014
# 83480788       WHITE    987121.0    217093.0  40.762554 -73.989638
# 87189586       WHITE   1032428.0    198872.0  40.712411 -73.826217
# 34021522       BLACK   1007288.0    236469.0  40.815707 -73.916772
# 63162514       WHITE    954943.0    148360.0  40.573850 -74.105496

# %%
def get_variable_types(df):
    return df.dtypes

# Get the variable types of the 'data' DataFrame
variable_types = get_variable_types(data)
numeric_columns = variable_types[variable_types == 'float64'].index.tolist() + variable_types[variable_types == 'int64'].index.tolist()
symbolic_columns = variable_types[variable_types == 'object'].index.tolist()

print("Numeric columns:", numeric_columns)
print("Symbolic columns:", symbolic_columns)
# Out:
# Numeric columns: ['PD_CD', 'KY_CD', 'JURISDICTION_CODE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude', 'ARREST_PRECINCT']
# Symbolic columns: ['ARREST_DATE', 'PD_DESC', 'OFNS_DESC', 'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE']

# %%
for column in symbolic_columns:
    print(f"{column}: {data[column].nunique()} unique values")
# Out:
# ARREST_DATE: 4568 unique values
# PD_DESC: 199 unique values
# OFNS_DESC: 57 unique values
# LAW_CODE: 464 unique values
# LAW_CAT_CD: 2 unique values
# ARREST_BORO: 5 unique values
# AGE_GROUP: 5 unique values
# PERP_SEX: 2 unique values
# PERP_RACE: 7 unique values

# %%
unique_arrest_boro = data['AGE_GROUP'].unique()
print(unique_arrest_boro)
# Out:
# ['25-44' '18-24' '65+' '45-64' '<18']

# %%
data['CLASS'] = data['JURISDICTION_CODE'].apply(lambda x: 0 if x < 3 else 1)
data.drop(columns=['LAW_CODE'], inplace=True)

# %%
# Define valid age groups
valid_age_groups = ['<18', '18-24', '25-44', '45-64', '65+']

# Replace erroneous values with NaN
data['AGE_GROUP'] = data['AGE_GROUP'].apply(lambda x: x if x in valid_age_groups else np.nan)

# %%
data['LAW_CAT_CD'] = data['LAW_CAT_CD'].map({'M': 0, 'F': 1})
data['PERP_SEX'] = data['PERP_SEX'].map({'M': 0, 'F': 1})
data['PERP_RACE'] = data['PERP_RACE'].map({
    'BLACK': 0,
    'WHITE': 1,
    'BLACK HISPANIC': 2,
    'WHITE HISPANIC': 3,
    'ASIAN / PACIFIC ISLANDER': 4,
    'AMERICAN INDIAN/ALASKAN NATIVE': 5
})
data['ARREST_BORO'] = data['ARREST_BORO'].map({
    'Q': 0,
    'M': 1,
    'K': 2,
    'B': 3,
    'S': 4
})

data['AGE_GROUP'] = data['AGE_GROUP'].map({
    '<18': 0,
    '18-24': 1,
    '25-44': 2,
    '45-64': 3,
    '65+': 4
})

# %%
variable_types = get_variable_types(data)
numeric_columns = variable_types[variable_types == 'float64'].index.tolist() + variable_types[variable_types == 'int64'].index.tolist()
symbolic_columns = variable_types[variable_types == 'object'].index.tolist()

print("Numeric columns:", numeric_columns)
print("Symbolic columns:", symbolic_columns)
# Out:
# Numeric columns: ['PD_CD', 'KY_CD', 'JURISDICTION_CODE', 'PERP_RACE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT', 'AGE_GROUP', 'PERP_SEX', 'CLASS']
# Symbolic columns: ['ARREST_DATE', 'PD_DESC', 'OFNS_DESC']

# %%
data.drop(columns=['PD_DESC', 'OFNS_DESC'], inplace=True)

# %%
data.drop(columns=['JURISDICTION_CODE'], inplace=True)

# %%
from math import sin, cos, pi
import pandas as pd
from pandas import DataFrame

# Ensure ARREST_DATE is parsed as datetime
data['ARREST_DATE'] = pd.to_datetime(data['ARREST_DATE'], errors='coerce')

def encode_cyclic_variables(data: DataFrame, vars: list[str]) -> None:
    for v in vars:
        x_max: float | int = max(data[v])
        data[v + "_sin"] = data[v].apply(lambda x: round(sin(2 * pi * x / x_max), 3))
        data[v + "_cos"] = data[v].apply(lambda x: round(cos(2 * pi * x / x_max), 3))
    return

# Extract day of the year for cyclic encoding
data['ARREST_DAYOFYEAR'] = data['ARREST_DATE'].dt.dayofyear

# Call the function (it modifies data in-place, so no need to assign)
encode_cyclic_variables(data, ['ARREST_DAYOFYEAR'])

# Display the first few rows
data.head()
# Out:
#            ARREST_DATE  PD_CD  KY_CD  LAW_CAT_CD  ARREST_BORO  \
# ARREST_KEY
# 173644106   2018-01-15  109.0  106.0           1            0
# 83480788    2012-03-04  101.0  344.0           0            1
# 87189586    2012-10-11  744.0  359.0           0            0
# 34021522    2007-08-27  478.0  343.0           0            3
# 63162514    2009-06-26  503.0  117.0           1            4
#
#             ARREST_PRECINCT  AGE_GROUP  PERP_SEX  PERP_RACE  X_COORD_CD  \
# ARREST_KEY
# 173644106               103          2         0        0.0   1040260.0
# 83480788                 18          1         0        1.0    987121.0
# 87189586                102          2         0        1.0   1032428.0
# 34021522                 40          2         0        0.0   1007288.0
# 63162514                122          4         1        1.0    954943.0
#
#             Y_COORD_CD   Latitude  Longitude  CLASS  ARREST_DAYOFYEAR  \
# ARREST_KEY
# 173644106     193180.0  40.696742 -73.798014      0                15
# 83480788      217093.0  40.762554 -73.989638      0                64
# 87189586      198872.0  40.712411 -73.826217      0               285
# 34021522      236469.0  40.815707 -73.916772      0               239
# 63162514      148360.0  40.573850 -74.105496      0               177
#
#             ARREST_DAYOFYEAR_sin  ARREST_DAYOFYEAR_cos
# ARREST_KEY
# 173644106                  0.255                 0.967
# 83480788                   0.891                 0.455
# 87189586                  -0.984                 0.179
# 34021522                  -0.820                -0.572
# 63162514                   0.103                -0.995

# %%
data.drop(columns=['ARREST_DATE'], inplace=True)
data.drop(columns=["LAW_CAT_CD"], inplace=True)

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.head()
# Out:
#    PD_CD  KY_CD  ARREST_BORO  ARREST_PRECINCT  AGE_GROUP  PERP_SEX  PERP_RACE  \
# 0  109.0  106.0            0              103          2         0        0.0
# 1  101.0  344.0            1               18          1         0        1.0
# 2  744.0  359.0            0              102          2         0        1.0
# 3  478.0  343.0            3               40          2         0        0.0
# 4  503.0  117.0            4              122          4         1        1.0
#
#    X_COORD_CD  Y_COORD_CD   Latitude  Longitude  CLASS  ARREST_DAYOFYEAR  \
# 0   1040260.0    193180.0  40.696742 -73.798014      0                15
# 1    987121.0    217093.0  40.762554 -73.989638      0                64
# 2   1032428.0    198872.0  40.712411 -73.826217      0               285
# 3   1007288.0    236469.0  40.815707 -73.916772      0               239
# 4    954943.0    148360.0  40.573850 -74.105496      0               177
#
#    ARREST_DAYOFYEAR_sin  ARREST_DAYOFYEAR_cos
# 0                 0.255                 0.967
# 1                 0.891                 0.455
# 2                -0.984                 0.179
# 3                -0.820                -0.572
# 4                 0.103                -0.995

# %%
data.to_csv("ny_arrests_enoded.csv", index=False)
